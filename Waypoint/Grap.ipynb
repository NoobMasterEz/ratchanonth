# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import ntpath

# %% [markdown]
# Reading file waypoint

# %%
data_waypoint = None
with open("waypoint_steering_lstm.txt","r") as file :
    data_waypoint = list((file.read()
    ).split(", \n"))
print(len(data_waypoint))
# Out:
# 4251

# %%
data_waypoint =  list(map(float, data_waypoint[:-1]))
print(data_waypoint.__len__())
# Out:
# 4250

# %% [markdown]
# After mod 5

# %%
data_waypoint = data_waypoint[0:len(data_waypoint):5]
print(data_waypoint.__len__())
# Out:
# 850

# %%
## Store data
datadir = 'data4'
#columns = ['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed']
data = pd.read_csv(os.path.join(datadir, 'driving_log.csv'))
pd.set_option('display.max_colwidth', -1)
data.head()
# Out:
# <ipython-input-5-eb0f6aa86fb3>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                                      center  \
# 0  C:\Users\ratchanonth_pl61\Desktop\IMG\center_2021_09_05_11_56_18_300.jpg
# 1  C:\Users\ratchanonth_pl61\Desktop\IMG\center_2021_09_05_11_56_18_405.jpg
# 2  C:\Users\ratchanonth_pl61\Desktop\IMG\center_2021_09_05_11_56_18_508.jpg
# 3  C:\Users\ratchanonth_pl61\Desktop\IMG\center_2021_09_05_11_56_18_635.jpg
# 4  C:\Users\ratchanonth_pl61\Desktop\IMG\center_2021_09_05_11_56_18_733.jpg
#
#                                                                      left  \
# 0  C:\Users\ratchanonth_pl61\Desktop\IMG\left_2021_09_05_11_56_18_300.jpg
# 1  C:\Users\ratchanonth_pl61\Desktop\IMG\left_2021_09_05_11_56_18_405.jpg
# ...

# %%
data = data["steering"]
print(data.__len__())
# Out:
# 880

# %%
data = data.to_list()

# %%
print(data.__len__())
# Out:
# 880

# %%
range_data = [*range(len(data))]
range_data_way=[*range(len(data_waypoint))]

# %%
plt.plot(range_data, data,label = "line 1")
plt.plot(range_data_way, data_waypoint,label = "line 2")

# %%
plt.plot(range_data, data,label = "line 1")

# %%
plt.plot(range_data_way, data_waypoint,label = "line 2")

# %%
data = pd.read_csv("Waypoint.csv")
pd.set_option('display.max_colwidth', -1)
data.head()
x_main = data["x"]
y_main = data["y"]
# Out:
# <ipython-input-4-73d5d2da456a>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
data1 = pd.read_csv("waypoint_lstm.csv")

x_car1 = data1["x"]
y_car1 = data1["z"]

# %%
data2 = pd.read_csv("waypoint_cnn.csv")

x_car2 = data2["x"]
y_car2 = data2["z"]

# %%
plt.plot(x_main,y_main,color='red', marker='*',label='Base Label Red')
plt.plot(x_car1,y_car1,color='blue',label='inceptionresnet Label Red')
plt.plot(x_car2,y_car2,color='green',label='LSTM Label Red')
plt.legend()
plt.show()
